# %% [markdown]
# Name : Arivazhagan.B
#
# Topic : Supermarket Sales Data visualization using seaborn
#
# Email : barivazhagan8@gmail.com

# %% [markdown]
# ## I will working with a Super_marketsales  dataset for these excercise.For now ,I will focus on the visualization of the data with seaborn.

# %% [markdown]
# Import necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\ELCOT\Desktop\csv file\Data Visualization\supermarket_sales - Sheet1.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# info()-It will give us to Number of rows and columns,data type ,memory usage and non -null value count in your dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# describe()-It will give us aggregate function. like a np.mean,np.max,np.min,np.std

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# Unique-It will give us to unique value in your specific column in your datasets

# %%
df['Branch'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %% [markdown]
# ## Branch-Wise total Bill

# %%
sns.set_style('whitegrid')
sns.set_context('poster',font_scale=0.5)
sns.barplot(x='Branch',y='Total',data=df,palette='rainbow')
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_41188\499278486.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Branch',y='Total',data=df,palette='rainbow')

# %% [markdown]
# head()-It will give us to first five index in your dataset.

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %% [markdown]
# ## Distribution of customers by City

# %%
plt.figure(figsize=(20,6))
sns.displot(df['City'],palette='rainbow')
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_41188\2887393543.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(df['City'],palette='rainbow')

# %% [markdown]
# ## Linear Relationship Between Total and Gross Income

# %%
sns.lmplot(x='Total',y='gross income',hue='Gender',data=df)
plt.show()

# %% [markdown]
# ## Total Bill amount Distribution by Genter

# %%
sns.barplot(x='Gender',y='Total',data=df,hue='City',palette='rainbow')
plt.legend(loc=1)
plt.show()

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %% [markdown]
# ## Total Bill by Product

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Product line',y='Total',data=df,palette='rainbow')
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_1424\1300726264.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product line',y='Total',data=df,palette='rainbow')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %% [markdown]
# # Number of Payment Transactions per Category

# %%
sns.countplot(x='Payment',data=df,palette='rainbow')
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_1424\3821752057.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Payment',data=df,palette='rainbow')

# %% [markdown]
# ## Box plot of Grocery Purchase Totals

# %%
sns.boxplot(x='Gender',y='Total',palette='rainbow',data=df)
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_1424\3164863105.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender',y='Total',palette='rainbow',data=df)

# %%
sns.violinplot(x='Branch',y='Total',hue='Gender',data=df)
plt.show()

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Product line',y='Rating',palette='rainbow',data=df)
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_1424\763350355.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product line',y='Rating',palette='rainbow',data=df)

# %%
df['Date']
# Out:
# 0      01-05-2019
# 1      03-08-2019
# 2      03-03-2019
# 3       1/27/2019
# 4      02-08-2019
#           ...
# 995     1/29/2019
# 996    03-02-2019
# 997    02-09-2019
# 998     2/22/2019
# 999     2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
corr=df[['Total','gross income']].corr()
corr
# Out:
#               Total  gross income
# Total           1.0           1.0
# gross income    1.0           1.0

# %%
sns.heatmap(corr,annot=True,linewidths=1,linecolor='yellow')
plt.show()

# %%
Facet=sns.FacetGrid(data=df,col='City',row='Gender')
Facet.map(plt.scatter,'Total','Unit price')
plt.show()
