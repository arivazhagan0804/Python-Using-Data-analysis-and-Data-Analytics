# %%
Name  : Arivazhagan.B

Topic : Pandas Excercise

Email : barivazhagan8@gmail.com

# %% [markdown]
# ## Pandas

# %% [markdown]
# *"Panel Data System" or "Python Data Analysis"-Wes Mckinney-2008*
#
# * It allow us to analze the big  data and make conclusion based on statistical theories.
#
# * It can clean messy data sets and make them readable and relevent.
#
# **Two method used in data Data Manipulation**
#
# Series-It is a one-dimentional array ,holding data of any type.
#
# Dataframe- It is a two-dimentional data structure,like two-dimentional array,or a table with rows and columns.

# %% [markdown]
# ## Series

# %% [markdown]
# **Create Series from python list**

# %%
import numpy as np
import pandas as np
L=[10,12,15,20]
S=np.Series(L)
S
# Out:
# 0    10
# 1    12
# 2    15
# 3    20
# dtype: int64

# %% [markdown]
# ***How to access the Series Data Element***

# %%
print(S[1])
print("*"*30)
print(S[0:3])
print('*'*30)
print(S[::-1])
# Out:
# 12
# ******************************
# 0    10
# 1    12
# 2    15
# dtype: int64
# ******************************
# 3    20
# 2    15
# 1    12
# 0    10
# dtype: int64

# %%
import numpy as np
ar=np.arange(6)
print(ar)
s1=pd.Series(ar,index=['A B C D E F'.split()])
s1
# Out:
# [0 1 2 3 4 5]
# A    0
# B    1
# C    2
# D    3
# E    4
# F    5
# dtype: int32

# %%
print(s1['A'])
# Out:
# 0

# %%
print(s1[['A','D']])
# Out:
# A    0
# D    3
# dtype: int32

# %% [markdown]
# **Creating Series from Dictionary**

# %%
dic={'Id':[202501,20252],'Name':['Hari','Sakthi'],'Deg':['B.sc','B.E'],'Role':['Admin','CAD Eng']}
print(dic)
s2=pd.Series(dic)
s2
# Out:
# {'Id': [202501, 20252], 'Name': ['Hari', 'Sakthi'], 'Deg': ['B.sc', 'B.E'], 'Role': ['Admin', 'CAD Eng']}
# Id       [202501, 20252]
# Name      [Hari, Sakthi]
# Deg          [B.sc, B.E]
# Role    [Admin, CAD Eng]
# dtype: object

# %% [markdown]
# **Creating DataFrame  from List**

# %%
from pandas import Series,DataFrame
li=[[10,15,20,25],[40,50,60,70]]
df=DataFrame(li,index=['r1','r2'],columns=['col1','col2','col3','col4'])
df
# Out:
#     col1  col2  col3  col4
# r1    10    15    20    25
# r2    40    50    60    70

# %%
df[['col1','col2']]
# Out:
#     col1  col2
# r1    10    15
# r2    40    50

# %% [markdown]
# **Creating DataFrame From Numpy random package**

# %%
from numpy.random import randn
df1=DataFrame(randn(3,3),columns=['x','y','z'])
df1
# Out:
#          x         y         z
# 0 -0.40914 -0.431575  0.427218
# 1 -3.59468  0.532413 -0.273431
# 2  1.84422 -1.805389 -0.519310

# %% [markdown]
# **Creating New column**

# %%
df1['new']=df1['x']+df1['y']
df1
# Out:
#          x         y         z       new
# 0 -0.40914 -0.431575  0.427218 -0.840714
# 1 -3.59468  0.532413 -0.273431 -3.062267
# 2  1.84422 -1.805389 -0.519310  0.038831

# %% [markdown]
# **How to removing column**

# %%
df1.drop('new',axis=1)
# Out:
#          x         y         z
# 0 -0.40914 -0.431575  0.427218
# 1 -3.59468  0.532413 -0.273431
# 2  1.84422 -1.805389 -0.519310

# %% [markdown]
# An important feature of pandas is a conditional Selection using bracket notation,Very similar to numpy.

# %% [markdown]
# **Conditional Selection**

# %%
df1
# Out:
#          x         y         z
# 0 -0.40914 -0.431575  0.427218
# 1 -3.59468  0.532413 -0.273431
# 2  1.84422 -1.805389 -0.519310

# %%
df1<0
# Out:
#        x      y      z
# 0   True   True  False
# 1   True  False   True
# 2  False   True   True

# %%
df1[df1<0]
# Out:
#          x         y         z
# 0 -0.40914 -0.431575       NaN
# 1 -3.59468       NaN -0.273431
# 2      NaN -1.805389 -0.519310

# %%
df1[df1['x']>0]
# Out:
#          x         y        z
# 2  1.84422 -1.805389 -0.51931

# %%
df1
# Out:
#          x         y         z
# 0 -0.40914 -0.431575  0.427218
# 1 -3.59468  0.532413 -0.273431
# 2  1.84422 -1.805389 -0.519310

# %%
df1[df1['y']>0]
# Out:
#          x         y         z
# 1 -3.59468  0.532413 -0.273431

# %%
df1[(df1['x']>0) & (df1['y']<0)]
# Out:
#          x         y        z
# 2  1.84422 -1.805389 -0.51931

# %% [markdown]
# **Add columns and Index**

# %%
dic={'Name':['hari','Sam','Kavi','Mahesh'],'Deg':['B.sc','M.E','B.E','M.Tech']}
print(dic)
df=DataFrame(dic)
df
# Out:
# {'Name': ['hari', 'Sam', 'Kavi', 'Mahesh'], 'Deg': ['B.sc', 'M.E', 'B.E', 'M.Tech']}
#      Name     Deg
# 0    hari    B.sc
# 1     Sam     M.E
# 2    Kavi     B.E
# 3  Mahesh  M.Tech

# %%
new_ind='A B C D'.split()
new_ind
# Out:
# ['A', 'B', 'C', 'D']

# %%
df['new_ind']=new_ind
df
# Out:
#            Name     Deg new_ind
# new_ind
# A          hari    B.sc       A
# B           Sam     M.E       B
# C          Kavi     B.E       C
# D        Mahesh  M.Tech       D

# %%
df.set_index('new_ind',inplace=True)

# %%
df
# Out:
#            Name     Deg new_ind
# new_ind
# A          hari    B.sc       A
# B           Sam     M.E       B
# C          Kavi     B.E       C
# D        Mahesh  M.Tech       D

# %% [markdown]
# **How to read dataset Using Pandas in Python**

# %% [markdown]
# ** Read in the Excel file us a dataframe called df **

# %%
import pandas as pd
import numpy as np
df=pd.read_excel(r"C:\Users\ELCOT\Desktop\csv file\netflix_titles.xlsx",'netflix_titles')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# head()-It will give us  first five index in your data set

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# tail-It will give us last five index in your dataset

# %%
df.tail()
# Out:
#      show_id     type               title         director  \
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
# 8806   s8807    Movie              Zubaan      Mozez Singh
# 8807   s8808  TV Show  Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie              Serena     Susanne Bier
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807         Shin Hyun-been, Jeon Yeo-bin, Goo Kyo-hwan    South Korea
# 8808  Bradley Cooper, Jennifer Lawrence, Toby Jones,...  United States
#
#             date_added  release_year rating  duration  \
# 8804  November 1, 2019          2009      R    88 min
# 8805  January 11, 2020          2006     PG    88 min
# ...

# %% [markdown]
# info-It will give us number of rowsand columns,Non-null value counts, data type and memory space in your dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8809 entries, 0 to 8808
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8809 non-null   object
#  1   type          8809 non-null   object
#  2   title         8809 non-null   object
#  3   director      6175 non-null   object
#  4   cast          7984 non-null   object
#  5   country       7978 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8809 non-null   int64
#  8   rating        8805 non-null   object
#  9   duration      8806 non-null   object
#  10  listed_in     8809 non-null   object
#  11  description   8809 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 826.0+ KB

# %% [markdown]
# sample-it will give us any random value in your dataset

# %%
df.sample()
# Out:
#      show_id   type              title       director  \
# 6379   s6380  Movie  Brooklyn's Finest  Antoine Fuqua
#
#                                                    cast        country  \
# 6379  Richard Gere, Don Cheadle, Ethan Hawke, Wesley...  United States
#
#            date_added  release_year rating duration          listed_in  \
# 6379  October 1, 2018          2009      R  133 min  Dramas, Thrillers
#
#                                             description
# 6379  Three cops find themselves hurtling toward the...

# %% [markdown]
# loc- It is useful when the index of the dataframe is a lable e.x: like a string

# %%
df.loc[0:2]
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %% [markdown]
# iloc-it workby looking  for the position in the dataframe

# %%
df.iloc[0]
# Out:
# show_id                                                        s1
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast                                                          NaN
# country                                             United States
# date_added                                     September 25, 2021
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# listed_in                                           Documentaries
# description     As her father nears the end of his life, filmm...
# Name: 0, dtype: object

# %% [markdown]
# isnull().sum()-It will give us to each columns Non-null value count in your dataset.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# columns-It will give us all coloumns title in your dataset

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# How to change the columns Names

# %%
new={'show_id':'Id','director':'direc','rating':'rat'}
new
# Out:
# {'show_id': 'Id', 'director': 'direc', 'rating': 'rat'}

# %%
df.rename(columns=new)
# Out:
#          Id     type                  title            direc  \
# 0        s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1        s2  TV Show          Blood & Water              NaN
# 2        s3  TV Show              Ganglands  Julien Leclercq
# 3        s4  TV Show  Jailbirds New Orleans              NaN
# 4        s5  TV Show           Kota Factory              NaN
# ...     ...      ...                    ...              ...
# 8804  s8805    Movie             Zombieland  Ruben Fleischer
# 8805  s8806    Movie                   Zoom     Peter Hewitt
# 8806  s8807    Movie                 Zubaan      Mozez Singh
# 8807  s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808  s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# we can show specific columns in your data

# %%
df[['title','director']]
# Out:
#                       title         director
# 0      Dick Johnson Is Dead  Kirsten Johnson
# 1             Blood & Water              NaN
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans              NaN
# 4              Kota Factory              NaN
# ...                     ...              ...
# 8804             Zombieland  Ruben Fleischer
# 8805                   Zoom     Peter Hewitt
# 8806                 Zubaan      Mozez Singh
# 8807     Parasyte: The Grey     Yeon Sang-ho
# 8808                 Serena     Susanne Bier
#
# [8809 rows x 2 columns]

# %% [markdown]
# IMDB-Internet movie Database

# %%
import numpy as np
IMDB=np.random.uniform(low=0,high=10,size=len(df['title']))
IMDB=np.around(IMDB,decimals=2)

# %% [markdown]
# Adding the "IMDB Rating" column as a new column

# %%
df['IMDB rating']=IMDB
df
# Out:
#      show_id     type                  title  \
# 0         s1    Movie   Dick Johnson Is Dead
# 1         s2  TV Show          Blood & Water
# 2         s3  TV Show              Ganglands
# 3         s4  TV Show  Jailbirds New Orleans
# 4         s5  TV Show           Kota Factory
# ...      ...      ...                    ...
# 8804   s8805    Movie             Zombieland
# 8805   s8806    Movie                   Zoom
# 8806   s8807    Movie                 Zubaan
# 8807   s8808  TV Show     Parasyte: The Grey
# 8808   s8809    Movie                 Serena
#
#                                             director  \
# 0                                    Kirsten Johnson
# 1     Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi
# 2                                    Julien Leclercq
# 3     Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi
# 4     Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi
# ...                                              ...
# ...

# %% [markdown]
# min- It give us minimum value in value in your specific column in your dataset

# %%
df['release_year'].min()
# Out:
# 1925

# %% [markdown]
# max-It give us max value in your data in your dataset

# %%
df['release_year'].max()
# Out:
# 2024

# %% [markdown]
# isnull-It will give we can show your nan null values index of your dataset

# %%
df[df.isnull().any(axis=1)]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %% [markdown]
# dropna- It will  drop nan value iteams which have values in any of the columns

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
# 8807   s8808  TV Show             Parasyte: The Grey         Yeon Sang-ho
# 8808   s8809    Movie                         Serena         Susanne Bier
#
#                                                    cast  \
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# **fillna()-It is used to fill your Non-null values in your dataset.

# %%
# Out:
# Series([], Name: cast, dtype: object)

# %%
df['director']=df['director'].fillna('Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...	',inplace=True)
df['cast']=df['cast'].fillna('Mel Giedroyc',inplace=True)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_36488\2986812582.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director']=df['director'].fillna('Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...	',inplace=True)
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_36488\2986812582.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        8809
# cast            8809
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# replace-It will give we can replace your columns values in your dataset

# %%
df.replace({'country':{'United States':'US','United Kingdom':'UK','South Africa':'SA'}})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast      country  \
# 0                                                   NaN           US
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...           SA
# ...

# %% [markdown]
# We can use aggregate function  in your dataset.Ex : mean,mode , median , min , max , std.

# %%
df['IMDB rating'].describe()
# Out:
# count    8809.000000
# mean        5.089582
# std         2.893573
# min         0.000000
# 25%         2.540000
# 50%         5.170000
# 75%         7.590000
# max        10.000000
# Name: IMDB rating, dtype: float64

# %% [markdown]
# unique-It will give unique iteam in every columns in your dataset

# %%
a=df['release_year'].unique()
# Out:
# array([2020, 2021, 1993, 2018, 1996, 1998, 1997, 2010, 2013, 2017, 1975,
#        1978, 1983, 1987, 2012, 2001, 2014, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 2019, 2016, 1982, 1989, 1990,
#        1991, 1999, 1986, 1992, 1984, 1980, 1961, 2000, 1995, 1985, 1976,
#        1959, 1988, 1981, 1972, 1964, 1945, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1925, 1974, 1960, 1966, 1971, 1962, 1969, 1977, 1967,
#        1968, 1965, 1946, 1942, 1955, 1944, 1947, 1943, 2024], dtype=int64)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# selecting row based on conditions

# %%
df[df['country']=='United States'].count()
# Out:
# show_id         2819
# type            2819
# title           2819
# director        2049
# cast            2489
# country         2819
# date_added      2813
# release_year    2819
# rating          2819
# duration        2816
# listed_in       2819
# description     2819
# IMDB rating     2819
# dtype: int64

# %%
df[['date_added','release_year']].count()
# Out:
# date_added      8799
# release_year    8809
# dtype: int64

# %%
isnull.any(axis=1)-It Will give us to No of null

# %%
df[df.isnull().any(axis=1)]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df.sample()
# Out:
#      show_id   type      title             director  \
# 8322   s8323  Movie  The Golem  Doron Paz, Yoav Paz
#
#                                                    cast country  \
# 8322  Hani Furstenberg, Ishai Golan, Kirill Cernyako...  Israel
#
#          date_added  release_year rating duration  \
# 8322  June 26, 2019          2018  TV-MA   95 min
#
#                                               listed_in  \
# 8322  Horror Movies, Independent Movies, Internation...
#
#                                             description
# 8322  As sickness spreads throughout the countryside...

# %%
df[df['country']=='Israel']
# Out:
#      show_id     type                title                 director  \
# 533     s534  TV Show              Shtisel                      NaN
# 833     s834  TV Show          Black Space                      NaN
# 2676   s2677  TV Show                Fauda                      NaN
# 4207   s4208  TV Show      When Heroes Fly                      NaN
# 4254   s4255  TV Show       Hashoter Hatov                      NaN
# 4776   s4777  TV Show           Mossad 101                      NaN
# 4826   s4827    Movie               Maktub                 Oded Raz
# 7082   s7083  TV Show    Inside the Mossad                      NaN
# 7625   s7626    Movie             Numbered  Dana Doron, Uriel Sinai
# 7991   s7992  TV Show      Shadow of Truth                      NaN
# 8115   s8116    Movie   Suicide (Hitabdut)            Benny Fredman
# 8322   s8323    Movie            The Golem      Doron Paz, Yoav Paz
# 8562   s8563    Movie  The Women's Balcony          Emil Ben-Shimon
#
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type               title         director  \
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
# 8806   s8807    Movie              Zubaan      Mozez Singh
# 8807   s8808  TV Show  Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie              Serena     Susanne Bier
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807         Shin Hyun-been, Jeon Yeo-bin, Goo Kyo-hwan    South Korea
# 8808  Bradley Cooper, Jennifer Lawrence, Toby Jones,...  United States
#
#             date_added  release_year rating  duration  \
# 8804  November 1, 2019          2009      R    88 min
# 8805  January 11, 2020          2006     PG    88 min
# ...

# %%
unique=df['release_year'].unique()
unique
# Out:
# array([2020, 2021, 1993, 2018, 1996, 1998, 1997, 2010, 2013, 2017, 1975,
#        1978, 1983, 1987, 2012, 2001, 2014, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 2019, 2016, 1982, 1989, 1990,
#        1991, 1999, 1986, 1992, 1984, 1980, 1961, 2000, 1995, 1985, 1976,
#        1959, 1988, 1981, 1972, 1964, 1945, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1925, 1974, 1960, 1966, 1971, 1962, 1969, 1977, 1967,
#        1968, 1965, 1946, 1942, 1955, 1944, 1947, 1943, 2024], dtype=int64)

# %%
unique=df['release_year'].unique()
df.sort_values(by='release_year')
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# ...      ...      ...                                            ...
# 857     s858  TV Show                                   The Neighbor
# 855     s856  TV Show                 Jurassic World Camp Cretaceous
# 853     s854    Movie                               Army of the Dead
# 965     s966  TV Show                                         Yasuke
# 8807   s8808  TV Show                             Parasyte: The Grey
#
#                                             director  \
# 4250  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi
# ...

# %%
df.drop_duplicates()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
a_2021=df[df['release_year']==2021] 
a_2021.count()
# Out:
# show_id         592
# type            592
# title           592
# director        297
# cast            494
# country         383
# date_added      592
# release_year    592
# rating          592
# duration        592
# listed_in       592
# description     592
# IMDB rating     592
# dtype: int64

# %% [markdown]
# What is the name of the highest rating movie?

# %%
df[df['release_year']==df['release_year'].max()]
# Out:
#      show_id     type               title      director  \
# 8807   s8808  TV Show  Parasyte: The Grey  Yeon Sang-ho
#
#                                             cast      country     date_added  \
# 8807  Shin Hyun-been, Jeon Yeo-bin, Goo Kyo-hwan  South Korea  April 5, 2024
#
#       release_year rating  duration               listed_in  \
# 8807          2024  TV-MA  1 Season  Sci-fi, Horror, Action
#
#                                             description  IMDB rating
# 8807  A new breed of parasitic aliens arrive on Eart...         2.25

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Maximum Movie released years?

# %%
y=df[df['country']==df['country']]['release_year'].value_counts().head()
y
# Out:
# release_year
# 2018    1038
# 2017     966
# 2019     913
# 2020     852
# 2016     838
# Name: count, dtype: int64

# %%
df.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description  IMDB rating
# 0  As her father nears the end of his life, filmm...         8.27

# %% [markdown]
# groupby()-This method to group rows together based of a column name.

# %%
df.groupby('release_year')['IMDB rating'].mean()
# Out:
# release_year
# 1925    3.770000
# 1942    6.440000
# 1943    5.243333
# 1944    6.516667
# 1945    3.657500
#           ...
# 2018    4.943252
# 2019    4.995932
# 2020    5.045813
# 2021    5.037838
# 2024    2.250000
# Name: IMDB rating, Length: 75, dtype: float64
