# %%
Namen : Arivazhagan.b

topic : plotly and cufflinks using data capstone projects 

Email : barivazhagan8@gmail.com

# %% [markdown]
# ## Mobiles dataset

# %% [markdown]
# For this capstone project we will be analyzing some Mobiles Launched data from [Kaggle]. The data contains the following fields:
#
#  * Company Name
#
#  * Model Name
#
#  * Mobile Weight
#
#  * RAM,Front Camera,Back Camera
#
#  * Processor,Battery Capacity,Screen Size
#
#  * Launched Prices in 5 regions : Pakistan,India,China,USA,Dubai
#
#  * Launched Year
#
#  Just go along with this notebook and try to complete the instructions or answer the questions in bold using my Python and Data Science skills!

# %% [markdown]
# ** import numpy and pandas **

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# **  Import visualization libraries **

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Read in csv file us dataframe called df **

# %%
df=pd.read_csv(r'C:\Users\ELCOT\Desktop\csv file\Data Visualization\Mobiles Dataset (2025).csv',encoding='cp1252')
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %% [markdown]
# info()-It will give us to No of rows and columns,dtype,Non-null value counts and memory  usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    object
#  10  Launched Price (India)     930 non-null    float64
#  11  Launched Price (China)     930 non-null    object
#  12  Launched Price (USA)       930 non-null    object
# ...

# %% [markdown]
# describe()-It will give us to aggregate function.like a np.count,np.max,np.min,np.std,np.mean

# %%
df.describe()
# Out:
#        Launched Price (India)  Launched Price (Dubai)  Launched Year
# count              930.000000              930.000000     930.000000
# mean             50576.818280             2183.933333    2022.193548
# std              40960.179361             1565.631642       1.862080
# min               5999.000000              299.000000    2014.000000
# 25%              19999.000000             1000.000000    2021.000000
# 50%              34999.000000             1675.000000    2023.000000
# 75%              74900.000000             3199.000000    2024.000000
# max             274999.000000            11099.000000    2025.000000

# %% [markdown]
# ## Distribution of Company Name

# %%
df['Company Name'].iplot(kind='histogram',title='Distribution of company Name',xTitle='Company Name',yTitle='Count')

# %%
df.head()
# Out:
#   Company Name            Model Name Mobile Weight  RAM Front Camera  \
# 0        Apple       iPhone 16 128GB          174g  6GB         12MP
# 1        Apple       iPhone 16 256GB          174g  6GB         12MP
# 2        Apple       iPhone 16 512GB          174g  6GB         12MP
# 3        Apple  iPhone 16 Plus 128GB          203g  6GB         12MP
# 4        Apple  iPhone 16 Plus 256GB          203g  6GB         12MP
#
#   Back Camera   Processor Battery Capacity Screen Size  \
# 0        48MP  A17 Bionic         3,600mAh  6.1 inches
# 1        48MP  A17 Bionic         3,600mAh  6.1 inches
# 2        48MP  A17 Bionic         3,600mAh  6.1 inches
# 3        48MP  A17 Bionic         4,200mAh  6.7 inches
# 4        48MP  A17 Bionic         4,200mAh  6.7 inches
#
#   Launched Price (Pakistan)  Launched Price (India) Launched Price (China)  \
# 0                 224999.00                 79999.0                5799.00
# ...

# %% [markdown]
# ## Company wise Mobiles sales Amount in India

# %%
df.iplot(kind='bar',x='Company Name',y='Launched Price (Pakistan)',title='Mobile Sales Amount in Pakistan',xTitle='Company Name',yTitle='Sales Amount')

# %%
df.iplot(kind='bar',x='Company Name',y='Launched Price (Pakistan)',title='Mobile Sales Amount in Pakistan',xTitle='Company Name',yTitle='Sales Amount')

# %% [markdown]
# ## Company wise Mobiles sales Amount in china

# %%
df.iplot(kind='bar',x='Company Name',y='Launched Price (China)',title='Mobile Sales Amount in China',xTitle='Company Name',yTitle='Sales Amount')

# %% [markdown]
# ## Company wise Mobiles sales Amount in USA

# %%
df.iplot(kind='bar',x='Company Name',y='Launched Price (USA)',title='Mobile Sales Amount in USA',xTitle='Company Name',yTitle='Sales Amount')

# %%
df.iplot(kind='bar',x='Company Name',y='Launched Price (Dubai)',title='Mobile Lanuched in Dubai',xTitle='Company Name',yTitle='Sales Amount')

# %% [markdown]
# ## Yearly Wise Mobile Launched Count

# %%
df['Launched Year'].iplot(kind='histogram',title='Yearly wise Mobile Launched count',xTitle='Year',yTitle='Mobile Count')

# %% [markdown]
# ## Yearly Wise Average Launched count in India

# %%
fig=px.pie(df,names='Launched Year',values='Launched Price (India)')
fig.show()
