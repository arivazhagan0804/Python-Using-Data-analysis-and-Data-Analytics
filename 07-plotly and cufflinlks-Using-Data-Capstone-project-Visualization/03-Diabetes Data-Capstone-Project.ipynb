# %% [markdown]
# Name  : Arivazhagan.B
#
# topic : plotly and cufflinks using data capstone projects
#
# Email : barivazhagan8@gmail.com

# %% [markdown]
# ## Diabetes dataset Capstone Project

# %% [markdown]
# For this capstone project we will be analyzing some Diabetes data from [Kaggle](https://www.kaggle.com/mchirico/montcoalert). The data contains the following fields:
#
# * Age- Age of the individual.
#
# * Pregnancies - Number of pregnancies
#
# * BloodPressure (mg/dl) - Diastolic blood pressure.
#
# * skinThickness - Skin fold thickness.
#
# * Insulin - Serum insulin.
#
# * BMI - Body Mass Index.
#
# * DiabetesPedigreeFunction - A function representing diabetes pedigree.
#
# Just go along with this notebook and try to complete the instructions or answer the questions in bold using my Python and Data Science skills!

# %% [markdown]
# ** import numpy and pandas **

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ** import visualization Libraries **

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Read in the csv file us a dataframe called df **

# %%
df=pd.read_csv(r'C:\Users\ELCOT\diabetes new.csv')
df
# Out:
#      Age  Pregnancies  Glucose  BloodPressure (mg/dL)  SkinThickness  Insulin  \
# 0     33            0      137                     40             35      168
# 1     31            0      118                     84             47      230
# 2     25            0      180                     66             39        0
# 3     31            0      100                     88             60      110
# 4     44            0      146                     82              0        0
# ..   ...          ...      ...                    ...            ...      ...
# 763   39           13      153                     88             37      140
# 764   46           14      100                     78             25      184
# 765   38           14      175                     62             30        0
# 766   43           15      136                     70             32      110
# 767   47           17      163                     72             41      114
#
# ...

# %% [markdown]
# info()-It will give us to No of rows and columns,Non-null values counts,dtype,memory space

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       768 non-null    int64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure (mg/dL)     768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
# dtypes: float64(2), int64(6)
# memory usage: 48.1 KB

# %% [markdown]
# describe()-It will give us to aggregate function.Like a np.min,np.max,np.mean,np.std,np.count.

# %%
df.describe()
# Out:
#               Age  Pregnancies     Glucose  BloodPressure (mg/dL)  \
# count  768.000000   768.000000  768.000000             768.000000
# mean    33.240885     3.845052  120.779948              69.105469
# std     11.760232     3.369578   32.243609              19.355807
# min     21.000000     0.000000    0.000000               0.000000
# 25%     24.000000     1.000000   99.000000              62.000000
# 50%     29.000000     3.000000  117.000000              72.000000
# 75%     41.000000     6.000000  140.250000              80.000000
# max     81.000000    17.000000  199.000000             122.000000
#
#        SkinThickness     Insulin         BMI  DiabetesPedigreeFunction
# count     768.000000  768.000000  768.000000                768.000000
# mean       20.536458   79.799479   31.992578                347.079349
# std        15.952218  115.244002    7.884160                254.431659
# min         0.000000    0.000000    0.000000                  0.100000
# ...

# %% [markdown]
# ## Create Histogram age wise count

# %%
df['Age'].iplot(kind='histogram',bins=10,xTitle='Age',yTitle='count',title='Distribution of Patients by Age')

# %% [markdown]
# ## Create Scatter Age vs Pregnancies

# %%
df.iplot(kind='scatter',x='Age',y='Pregnancies',mode='markers',title='Age wise pregnancies',xTitle='Age',yTitle='Pregnancies')

# %% [markdown]
# ## create Scatter Age vs Glucose

# %%
df.iplot(kind='scatter',x='Age',y='Glucose',title='Age vs Glucose Scatter',mode='markers',asFigur=True,xTitle='Age',yTitle='Glucose_range')

# %% [markdown]
# ## Create Scatter Age vs BloodPressure

# %%
df.iplot(kind='scatter',x='Age',y='BloodPressure (mg/dL)',mode='markers',xTitle='Age',yTitle='BloodPressure',title='Age vs BloodPressure')

# %%
df.head()
# Out:
#    Age  Pregnancies  Glucose  BloodPressure (mg/dL)  SkinThickness  Insulin  \
# 0   33            0      137                     40             35      168
# 1   31            0      118                     84             47      230
# 2   25            0      180                     66             39        0
# 3   31            0      100                     88             60      110
# 4   44            0      146                     82              0        0
#
#     BMI  DiabetesPedigreeFunction
# 0  43.1                     2.288
# 1  45.8                   551.000
# 2  42.0                     1.893
# 3  46.8                   962.000
# 4  40.5                     1.781

# %% [markdown]
# ## Create Boxplot

# %%
df.iplot(kind='box',x='Age',y='BMI',title='Boxplot')

# %% [markdown]
# ## Create Correlation Heatmap

# %%
df.corr().iplot(kind='heatmap',title='Correlation Heatmap')
