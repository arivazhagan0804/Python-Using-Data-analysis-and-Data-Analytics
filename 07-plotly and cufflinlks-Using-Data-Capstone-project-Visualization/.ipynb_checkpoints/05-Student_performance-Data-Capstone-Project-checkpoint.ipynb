# %% [markdown]
# Name : Arivazhagan.B
#
# Topic : Plotly and cufflinks using data visualization
#
# Email : arivazhagan45678@gmail.com

# %% [markdown]
# ## Student Performance Dataset

# %% [markdown]
# 1.For this capstone project I will be analyzing some Student performance data from [Kaggle]. The data contains the following fields:
#
# * gender- Gender of the student(e.g.,male,female)
#
# * race/ethniccity - Ethnic group category (e.g., group A,group B,etc.)
#
# * parental level of education - Education level of the student's parents
#
# * lunch - Type of lunch (e.g., standard,free/reduced)
#
# * test perparation course - Whether the studen completed a test prepatation course.
#
# * math score - Score in math(integer)
#
# * reading score - Score in reading(integer)
#
# * writting Score - Score in writing (integer)

# %% [markdown]
# **import numpy and pandas **

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ** import visualization libraries **

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Read in csv file us daraframe called df **

# %%
df=pd.read_csv(r'C:\Users\ELCOT\StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# info()-It will give us to No of rows and columns,dtype,Non-null values and memory storage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# describe-It will give us to aggregate functions.like a np.count,np.max,np.min,np.std,np.mean.

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# unique-It will give us unique values in a column.

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %% [markdown]
# ## Math Scores by Parental Level of Education

# %%
fig1=px.bar(df,x='parental level of education',y='math score')
fig1.show()

# %% [markdown]
# ## Reading Score by Parental Level of Education

# %%
fig2=px.histogram(df,x='parental level of education',y='reading score')
fig2

# %% [markdown]
# ## Distribution of Math Scores by Parental Level of Education

# %%
fig3=px.box(df,x='parental level of education',y='math score')
fig3

# %% [markdown]
# ## Histogram of Parental Level of Education

# %%
fig4=px.histogram(df['parental level of education'])
fig4.show()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Count for Test Preparation Score

# %%
fig5=px.histogram(df['test preparation course'])
fig5.show()

# %% [markdown]
# ## Relationship Between Math and Reading Scores

# %%
fig6=px.scatter(df,x='math score',y='reading score',color='parental level of education')
fig6.show()

# %% [markdown]
# ## Average Writing Scores by Race

# %%
fig7=px.pie(df,names='race/ethnicity',values='math score',)
fig7.show()

# %% [markdown]
# ## Average Reating Scores by Race

# %%
fig8=px.pie(df,names='race/ethnicity',values='reading score')
fig8.show()

# %% [markdown]
# ## Average Writing Scores by Grade Group

# %%
fig9=px.pie(df,names='race/ethnicity',values='writing score')
fig9.show()

# %% [markdown]
# ## Create New column Total Score

# %%
total_score=df['math score']+df['reading score']+df['writing score']
total_score
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
df['total score']=total_score
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ## Average Total Score by Parental Level of Education

# %%
fig9=px.bar(df,x='parental level of education',y='total score')
fig9.show()

# %% [markdown]
# ## 3d_line plot

# %%
fig10=px.line_3d(df,x='race/ethnicity',y='parental level of education',z='gender',color='total score')
fig10.show()

# %% [markdown]
# ## Create pivot  table

# %%
pivot_table=df.pivot_table(index='parental level of education',columns='race/ethnicity',values='total score')
pivot_table
# Out:
# race/ethnicity                  group A     group B     group C     group D  \
# parental level of education
# associate's degree           191.642857  203.926829  208.128205  208.000000
# bachelor's degree            203.583333  213.900000  219.725000  209.607143
# high school                  183.833333  184.500000  186.984375  190.431818
# master's degree              190.000000  224.500000  207.105263  229.434783
# some college                 194.666667  193.135135  203.420290  211.313433
# some high school             179.583333  192.868421  189.469388  205.840000
#
# race/ethnicity                  group E
# parental level of education
# associate's degree           221.923077
# bachelor's degree            226.777778
# high school                  208.636364
# master's degree              237.250000
# some college                 216.657143
# some high school             208.222222

# %% [markdown]
# ##  Headmap of total Score by Race and Parental Level of Education

# %%
pivot_table.iplot(kind='heatmap')
