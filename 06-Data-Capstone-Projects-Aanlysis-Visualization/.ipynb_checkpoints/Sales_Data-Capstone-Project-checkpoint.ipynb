# %%
Name : Arivazhagan.B

Title : Data visualization using python 

Email : arivazhagan45678@gmail.com

# %% [markdown]
# ## Sales Transaction Dataset visualization

# %% [markdown]
# I will working with a #Sales Transaction Dataset visualization# dataset for these excercise.For now ,I will focus on the visualization of the data.

# %% [markdown]
# ## Sales Transactions Dataset

# %% [markdown]
# ## Description :
#
#  ## This dataset contains detailed sales transaction records from various.It includes informatin about product sold,sales representatives,regions,sales amount,discounts,customer types,and payment methods .The dataset is suitable for sales performance analysis,trend evaluation,and customer segmentation.

# %% [markdown]
# Import Visualization libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ** Read in the the csv file as a data frame called df **

# %%
df=pd.read_csv(r'C:\Users\ELCOT\Desktop\csv file\Data Visualization\sales_data.csv')
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %% [markdown]
# info() = It will give us to no of rows and columns,non-null values counts,data type and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   object
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# ...

# %% [markdown]
# describe - It will give us to aggregate functions.Ex : np.count,np.mean,np.std,np.min,np.max.

# %%
df.describe()
# Out:
#         Product_ID  Sales_Amount  Quantity_Sold    Unit_Cost   Unit_Price  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          Discount
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %% [markdown]
# Unique() - It will give us to unique values in your specific columns in your dataset.

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %% [markdown]
# ## Total Sales by Region

# %%
sns.set_style('whitegrid')
sns.set_context('poster',font_scale=0.5)
sns.barplot(x='Region',y='Sales_Amount',data=df,palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7824\2665557556.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Region',y='Sales_Amount',data=df,palette='rainbow')
# <Axes: xlabel='Region', ylabel='Sales_Amount'>

# %% [markdown]
# ## Sales Trend Over Time

# %%
df['Sale_Date']=pd.to_datetime(df['Sale_Date'])

Monthly_sale=df.groupby(df['Sale_Date'])['Sales_Amount'].sum()
Monthly_sale
# Out:
# Sale_Date
# 2023-01-01    14141.12
# 2023-01-02     6452.79
# 2023-01-03    21319.08
# 2023-01-04    30175.06
# 2023-01-05    16708.75
#                 ...
# 2023-12-28     7976.44
# 2023-12-29    20842.53
# 2023-12-30    26107.95
# 2023-12-31    28608.37
# 2024-01-01    19328.01
# Name: Sales_Amount, Length: 340, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')
Monthly_sale.plot.line()
plt.xlabel('Sale Date')
plt.ylabel('Sale Amount')
plt.title('Monthly Wise sales')
# Out:
# Text(0.5, 1.0, 'Monthly Wise sales')

# %% [markdown]
# ## Sales Amount by Customer Type

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Customer_Type',y='Sales_Amount',data=df,hue='Region')
plt.legend(loc=1)

# %% [markdown]
# ## Top Sales Reps

# %%
S=sns.barplot(x='Sales_Rep',y='Sales_Amount',data=df,palette='rainbow')
S.set_title('Top Sale Reps')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7824\2008361874.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   S=sns.barplot(x='Sales_Rep',y='Sales_Amount',data=df,palette='rainbow')
# Text(0.5, 1.0, 'Top Sale Reps')

# %% [markdown]
# ## Sales_Channel Wise Sales

# %%
S=sns.barplot(x='Sales_Channel',y='Sales_Amount',data=df,palette='rainbow')
S.set_title('Sales Channel Wise Sales')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7824\1801937244.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   S=sns.barplot(x='Sales_Channel',y='Sales_Amount',data=df,palette='rainbow')
# Text(0.5, 1.0, 'Sales Channel Wise Sales')

# %% [markdown]
# ## Product_Category wise Sales

# %%
plt.figure(figsize=(10,6))
P=sns.barplot(x='Product_Category',y='Sales_Amount',data=df,hue='Region',palette='rainbow')
P.set_title('Product Category Wise Sales')
plt.legend(loc=1)

# %% [markdown]
# ## Product Wise Discount

# %%
sns.barplot(x='Product_Category',y='Discount',data=df,palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7824\2202867582.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product_Category',y='Discount',data=df,palette='rainbow')
# <Axes: xlabel='Product_Category', ylabel='Discount'>

# %% [markdown]
# ## Headmap of Total Sales Amount by Region and Sales Representative

# %%
pivot=df.pivot_table(index='Region', columns='Sales_Rep',values='Sales_Amount')
pivot
# Out:
# Sales_Rep        Alice          Bob      Charlie        David          Eve
# Region
# East       5015.182115  5164.601833  4464.133514  4823.957797  4351.652727
# North      5200.983750  5306.018409  5450.709273  5045.344107  4752.690625
# South      5320.323111  5024.008600  4879.396250  5561.017679  4559.958605
# West       4589.160426  5304.616296  5326.863333  5160.148824  4906.227021

# %%
plt.figure(figsize=(10,6))
sns.heatmap(pivot,annot=True,linewidths=1)
# Out:
# <Axes: xlabel='Sales_Rep', ylabel='Region'>
