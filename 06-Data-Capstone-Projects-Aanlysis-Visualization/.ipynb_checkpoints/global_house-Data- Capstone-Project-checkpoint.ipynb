# %% [markdown]
# Name : Arivazhagan.B
#
# Practice : Data visualization in python
#
# Email : arivazhagan45678@gmail.com

# %% [markdown]
# ## Glopal house marketing visualization

# %% [markdown]
# I will working with a # global_housing_market_extended# dataset for these excercise.For now ,I will focus on the visualization of the data.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\ELCOT\csv file\global_housing_market_extended.csv')
df
# Out:
#     Country  Year  House Price Index  Rent Index  Affordability Ratio  \
# 0       USA  2015         117.454012  116.550001             9.587945
# 1       USA  2016         150.807258   51.440915            11.729189
# 2       USA  2017         123.194502   70.386040             8.506676
# 3       USA  2018         131.423444   91.469020             3.418054
# 4       USA  2019         110.461377   56.837048             9.158097
# ..      ...   ...                ...         ...                  ...
# 195     UAE  2020         160.153711  117.170365             7.390686
# 196     UAE  2021          95.004866   72.727315             9.636214
# 197     UAE  2022         175.533469  105.083237             5.838662
# 198     UAE  2023         126.147746   94.604103             8.934185
# 199     UAE  2024         153.743377   85.855534             9.122050
#
#      Mortgage Rate (%)  Inflation Rate (%)  GDP Growth (%)  \
# 0             4.493292            1.514121       -0.752044
# ...

# %% [markdown]
# info()- It will give us to no of rows and columns,data type,non null values,memory usage in your dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                200 non-null    object
#  1   Year                   200 non-null    int64
#  2   House Price Index      200 non-null    float64
#  3   Rent Index             200 non-null    float64
#  4   Affordability Ratio    200 non-null    float64
#  5   Mortgage Rate (%)      200 non-null    float64
#  6   Inflation Rate (%)     200 non-null    float64
#  7   GDP Growth (%)         200 non-null    float64
#  8   Population Growth (%)  200 non-null    float64
#  9   Urbanization Rate (%)  200 non-null    float64
#  10  Construction Index     200 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 17.3+ KB

# %% [markdown]
# unique-It will give us we can show your spcific column unique values

# %%
df['Country'].unique()
# Out:
# array(['USA', 'Canada', 'UK', 'Germany', 'France', 'Italy', 'Spain',
#        'Australia', 'India', 'China', 'Japan', 'Brazil', 'South Korea',
#        'Mexico', 'South Africa', 'Russia', 'Netherlands', 'Sweden',
#        'Switzerland', 'UAE'], dtype=object)

# %%
df['Year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
#       dtype=int64)

# %% [markdown]
# ## Year-Wise Rent Amount in India

# %%
India=df[df['Country']=='India']
India
# Out:
#    Country  Year  House Price Index  Rent Index  Affordability Ratio  \
# 80   India  2015         173.834046   62.686315             3.598466
# 81   India  2016          96.365594   61.498606            10.331172
# 82   India  2017         123.913491   76.386110             7.164118
# 83   India  2018         134.355286  113.453048             8.618142
# 84   India  2019         142.007276   87.342276            11.045033
# 85   India  2020         136.988968  103.372108            10.890891
# 86   India  2021         159.729537   60.494220             5.063263
# 87   India  2022         114.569599   62.711840            11.176055
# 88   India  2023         130.588868   92.801796             3.162992
# 89   India  2024          95.253904   90.340185             8.460435
#
#     Mortgage Rate (%)  Inflation Rate (%)  GDP Growth (%)  \
# 80           5.205603            4.234075        4.734630
# 81           4.825986            3.899925        0.870644
# ...

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')
India.plot.bar(x='Year',y='Rent Index')
plt.xlabel('Year')
plt.ylabel('Rent')
plt.title('Year-Wise Rent Amount(India)')
plt.show()

# %% [markdown]
# ## Rent Amount in All Country

# %%
rent=df.groupby('Country')['Rent Index'].mean().sort_values()
rent
# Out:
# Country
# Japan           74.044817
# France          75.032904
# Australia       75.269638
# UK              77.341511
# Switzerland     77.543344
# Russia          80.047968
# South Korea     80.808085
# India           81.108650
# USA             82.294457
# Sweden          82.622095
# UAE             82.668792
# Netherlands     82.882051
# Spain           82.900602
# Canada          86.148975
# China           86.591358
# Italy           88.637664
# Germany         88.655377
# Brazil          88.799770
# Mexico          93.277990
# South Africa    94.291355
# Name: Rent Index, dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.barplot(rent)
plt.show()

# %% [markdown]
# ## Year-wise House Price Index

# %%
price=df.groupby('Year')['House Price Index'].mean()
price
# Out:
# Year
# 2015    139.227551
# 2016    120.354279
# 2017    130.374609
# 2018    127.793459
# 2019    123.056015
# 2020    132.257842
# 2021    142.144052
# 2022    120.314413
# 2023    130.116069
# 2024    138.171933
# Name: House Price Index, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')
price.plot.line(marker='o',markerfacecolor='yellow')
plt.xlabel('price')
plt.ylabel('House Price Index')
plt.title('Year-wise House Price Index')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#   Country  Year  House Price Index  Rent Index  Affordability Ratio  \
# 0     USA  2015         117.454012  116.550001             9.587945
# 1     USA  2016         150.807258   51.440915            11.729189
# 2     USA  2017         123.194502   70.386040             8.506676
# 3     USA  2018         131.423444   91.469020             3.418054
# 4     USA  2019         110.461377   56.837048             9.158097
#
#    Mortgage Rate (%)  Inflation Rate (%)  GDP Growth (%)  \
# 0           4.493292            1.514121       -0.752044
# 1           5.662213            1.880204       -0.545400
# 2           2.197469            2.398940        0.930895
# 3           4.537724            1.608407       -1.479587
# 4           3.700762            1.293249        1.961415
#
#    Population Growth (%)  Urbanization Rate (%)  Construction Index
# 0              -0.796707              85.985284          118.089201
# 1              -0.358084              69.127267          111.980514
# ...

# %% [markdown]
# ## Year- wise GDP Growth

# %%
year=df.groupby('Year')['GDP Growth (%)'].mean()
year
# Out:
# Year
# 2015    1.911071
# 2016    2.180306
# 2017    2.449061
# 2018    2.237369
# 2019    2.164606
# 2020    2.200618
# 2021    1.872846
# 2022    1.906202
# 2023    1.656822
# 2024    2.758321
# Name: GDP Growth (%), dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')
year.plot.line(marker='o',markerfacecolor='yellow')
plt.xlabel('Year')
plt.ylabel('GDP Growth')
plt.title('Year-wise GDP Growth')
plt.legend()
plt.show()

# %%
population=df.groupby('Country')['Population Growth (%)'].mean().sort_values()
population
# Out:
# Country
# UAE            -0.104929
# Italy           0.197881
# South Africa    0.277036
# Germany         0.313504
# Canada          0.382892
# Russia          0.525485
# Australia       0.559129
# Sweden          0.672139
# USA             0.689643
# Mexico          0.712611
# Switzerland     0.740293
# Japan           0.753841
# Spain           0.762673
# China           0.828688
# UK              0.980809
# Netherlands     1.022862
# India           1.079869
# France          1.315331
# South Korea     1.362889
# Brazil          1.383479
# Name: Population Growth (%), dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.set_style('whitegrid')
f=sns.barplot(population)
f.set(xlabel='Country',
      ylabel='Population Growth',
      title='Country-wise Population Growth')
# Out:
# [Text(0.5, 0, 'Country'),
#  Text(0, 0.5, 'Population Growth'),
#  Text(0.5, 1.0, 'Country-wise Population Growth')]

# %%
pivot=df.pivot_table(columns='Year',index='Country',values='Rent Index')
pivot
# Out:
# Year                2015        2016        2017        2018        2019  \
# Country
# Australia     112.664479   51.404984   84.890954   95.214207   61.247696
# Brazil         98.628753   62.959305   84.259747  114.084181  109.118458
# Canada         99.927135   52.200043   55.388594  112.479130  110.251141
# China         108.722866  106.199741   81.655256   90.641185  119.781198
# France         95.030175   57.054460   69.729834  102.543033   80.029582
# Germany       106.707938  112.300374   91.358328   93.602333   72.606953
# India          62.686315   61.498606   76.386110  113.453048   87.342276
# Italy          89.088297   58.226837  117.425578  117.851178   69.667423
# Japan          51.857254   91.320646   59.807922   94.343475  114.000917
# Mexico        118.683032  117.409440   99.572046  102.475628   81.213189
# Netherlands    56.573050   84.802233   96.121983  110.952742  103.359959
# Russia         90.507279  113.865434   66.628033   75.146336   59.161156
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(data=pivot,annot=True,linewidths=1)
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_40616\1049242584.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df
# Out:
#     Country  Year  House Price Index  Rent Index  Affordability Ratio  \
# 0       USA  2015         117.454012  116.550001             9.587945
# 1       USA  2016         150.807258   51.440915            11.729189
# 2       USA  2017         123.194502   70.386040             8.506676
# 3       USA  2018         131.423444   91.469020             3.418054
# 4       USA  2019         110.461377   56.837048             9.158097
# ..      ...   ...                ...         ...                  ...
# 195     UAE  2020         160.153711  117.170365             7.390686
# 196     UAE  2021          95.004866   72.727315             9.636214
# 197     UAE  2022         175.533469  105.083237             5.838662
# 198     UAE  2023         126.147746   94.604103             8.934185
# 199     UAE  2024         153.743377   85.855534             9.122050
#
#      Mortgage Rate (%)  Inflation Rate (%)  GDP Growth (%)  \
# 0             4.493292            1.514121       -0.752044
# ...

# %%
sns.jointplot(x='House Price Index',y='Mortgage Rate (%)',data=df)

# %%
populationgrowth=df.pivot_table(columns='Year',index-'Country',values='Population Growth(%)')
populationgrowth
# Out:
#   Cell In[123], line 1
#     populationgrowth=df.pivot_table(columns='Year',index-'Country',values='Population Growth(%)')
#                                                                                                 ^
# SyntaxError: positional argument follows keyword argument
